# %%
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import time

# Initialize tseconds")

    # Plotting the graph with optimal path highlighted
    pos = {f'City {i}': coordinates[i] for i in range(len(coordinates))}
    plt.figure(figsize=(12, 8))
    nx.draw(G, pos, with_labels=True, node_size=700, node_color='lightblue', font_size=8, edge_color='gray')
    path_edges = list(zip(optimal_path, optimal_path[1:] + optimal_path[:1]))
    nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=2)
    plt.title('Optimal Traveling Salesman Path')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Optimal Path: ('City 1', 'City 6', 'City 4', 'City 10', 'City 3', 'City 5', 'City 0', 'City 7', 'City 2', 'City 8', 'City 9', 'City 11')
# Minimum Distance: 372.81 units
# Computation Time: 3959.0491 seconds
